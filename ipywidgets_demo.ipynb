# %% [markdown]
# # Jupyter Widgets - простые примеры
#
# GitHub [jupyter-widgets](https://github.com/jupyter-widgets). Есть учебник
#
# [Jupyter Widgets 8.1.1 documentation](https://ipywidgets.readthedocs.io/en/stable/index.html#) Основная страница с примерами
#
# Можно открыть, попробовать, скачать любой пример и попробовать у себя локально, например в Pycharm Pro
#
# Для использования требуется пакет `ipywidgets`

# %%
from time import sleep
from itertools import cycle

import ipywidgets as widgets
from IPython.display import display

style = cycle(['', 'success', 'info', 'warning', 'danger'])
pb = widgets.IntProgress(
    value=7,
    min=0,
    max=10,
    bar_style='info', # 'success', 'info', 'warning', 'danger' or ''
    # style={'bar_color': 'maroon'},
    orientation='horizontal'
)
display(pb)

total = 10
for i in range(total):
    pb.value = i + 1
    pb.bar_style = style.__next__()
    pb.description = f"{round((i + 1) / total * 100, 0):>4}%"
    sleep(1)
# Out:
# IntProgress(value=7, bar_style='info', max=10)

# %%
from IPython.display import display
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
w.value = 50

# %%
a = widgets.IntSlider(description='a')
b = widgets.IntSlider(description='b')
c = widgets.IntSlider(description='c')
def f(a, b, c):
    print('{}*{}*{}={}'.format(a, b, c, a*b*c))

out = widgets.interactive_output(f, {'a': a, 'b': b, 'c': c})

widgets.HBox([widgets.VBox([a, b, c]), out])

# %%
a.value = 10
